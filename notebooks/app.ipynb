# %%
# !python app.py
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %%
# !pip install ipykernel

# %%
import pandas as pd

# %%
# !pip install requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 513.4 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from asinparser import AsinParser
from glob import glob

import warnings
warnings.filterwarnings("ignore")

asin = 'B08MWS95QG'
asin_parser = AsinParser()
reviews = asin_parser.get_reviews(asin)
df = pd.DataFrame(reviews)

# %%
df = pd.read_csv('aws_reviews_sample.csv')
asin = 'B08MWS95QG'
df_asin = df[df['asin'] == asin]
if df_asin.empty:
    asin_parser = AsinParser()
    reviews = asin_parser.get_reviews(asin)
    df_asin = pd.DataFrame(reviews)
    df_asin['asin'] = asin
    df = pd.concat([df,df_asin])

# %%
df
# Out:
#           asin                                             review  \
# 0   B09S6FWS7W  \nI have a newer style faucet in my house and ...
# 1   B09S6FWS7W  \nWatch the girth of your faucet! Mine faucet ...
# 2   B09S6FWS7W  \nMy faucet is a large spout with built in pul...
# 3   B09S6FWS7W  \nThey should state that it only fits very nar...
# 4   B09S6FWS7W  \nThe product idea is genius, but our faucet i...
# ..         ...                                                ...
# 45  B08MWS95QG                                               None
# 46  B08MWS95QG  wide enough for 1 person, and I think it will ...
# 47  B08MWS95QG  idéal pour le camping je suis tres satisfaite ...
# 48  B08MWS95QG  If you use this, you need to use it INSIDE an ...
# 49  B08MWS95QG  The unit doesn’t heat and isn’t worth the mone...
#
#                                          review_title  \
# 0                                                 NaN
# 1                                                 NaN
# ...

# %%
 df[df['asin'] == asin].empty
# Out:
# True

# %%
pd.concat([df,tmp])
# Out:
#           asin                                             review  \
# 0   B09S6FWS7W  \nI have a newer style faucet in my house and ...
# 1   B09S6FWS7W  \nWatch the girth of your faucet! Mine faucet ...
# 2   B09S6FWS7W  \nMy faucet is a large spout with built in pul...
# 3   B09S6FWS7W  \nThey should state that it only fits very nar...
# 4   B09S6FWS7W  \nThe product idea is genius, but our faucet i...
# ..         ...                                                ...
# 45           0                                               None
# 46           0  wide enough for 1 person, and I think it will ...
# 47           0  idéal pour le camping je suis tres satisfaite ...
# 48           0  If you use this, you need to use it INSIDE an ...
# 49           0  The unit doesn’t heat and isn’t worth the mone...
#
#                                          review_title  \
# 0                                                 NaN
# 1                                                 NaN
# ...
