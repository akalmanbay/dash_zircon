# %%
from dash import Dash, dcc, html
from dash.dependencies import Input, Output, State
from flask_caching import Cache
# from asinparser import AsinParser
from wordcloud import WordCloud, STOPWORDS
import pandas as pd
import os
import plotly.graph_objs as go

# %%
df = pd.read_csv('aws_reviews_sample.csv')

# %%
wordcloud, frequency_figure, treemap = plotly_wordcloud(df)

# %%
wordcloud

# %%
d = {'f':0.5, 'd' : 0.001}

# %%
import matplotlib.pyplot as plt
wordcloud = WordCloud(stopwords=set(STOPWORDS), max_words=100, max_font_size=90).fit_words(d)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
"""A wonderful function that returns figure data for three equally
wonderful plots: wordcloud, frequency histogram and treemap"""
complaints_text = list(df["review"].dropna().values)

# join all documents in corpus
text = " ".join(list(complaints_text))

word_cloud = WordCloud(stopwords=set(STOPWORDS), max_words=100, max_font_size=90)
word_cloud.generate(text)

word_list = []
freq_list = []
fontsize_list = []
position_list = []
orientation_list = []
color_list = []

for (word, freq), fontsize, position, orientation, color in word_cloud.layout_:
    word_list.append(word)
    freq_list.append(freq)
    fontsize_list.append(fontsize)
    position_list.append(position)
    orientation_list.append(orientation)
    color_list.append(color)

# get the positions
x_arr = []
y_arr = []
for i in position_list:
    x_arr.append(i[0])
    y_arr.append(i[1])

# get the relative occurence frequencies
new_freq_list = []
for i in freq_list:
    new_freq_list.append(i * 80)

trace = go.Scatter(
    x=x_arr,
    y=y_arr,
    textfont=dict(size=new_freq_list, color=color_list),
    hoverinfo="text",
    textposition="top center",
    hovertext=["{0} - {1}".format(w, f) for w, f in zip(word_list, freq_list)],
    mode="text",
    text=word_list,
)

layout = go.Layout(
    {
        "xaxis": {
            "showgrid": False,
            "showticklabels": False,
            "zeroline": False,
            "automargin": True,
            "range": [-100, 250],
        },
        "yaxis": {
            "showgrid": False,
            "showticklabels": False,
            "zeroline": False,
            "automargin": True,
            "range": [-100, 450],
        },
        "margin": dict(t=20, b=20, l=10, r=10, pad=4),
        "hovermode": "closest",
    }
)

wordcloud_figure_data = {"data": [trace], "layout": layout}
word_list_top = word_list[:25]
word_list_top.reverse()
freq_list_top = freq_list[:25]
freq_list_top.reverse()

frequency_figure_data = {
    "data": [
        {
            "y": word_list_top,
            "x": freq_list_top,
            "type": "bar",
            "name": "",
            "orientation": "h",
        }
    ],
    "layout": {"height": "550", "margin": dict(t=20, b=20, l=100, r=20, pad=4)},
}
treemap_trace = go.Treemap(
    labels=word_list_top, parents=[""] * len(word_list_top), values=freq_list_top
)
treemap_layout = go.Layout({"margin": dict(t=10, b=10, l=5, r=5, pad=4)})
treemap_figure = {"data": [treemap_trace], "layout": treemap_layout}
# Out:
#   Input In [27]
#     return wordcloud_figure_data, frequency_figure_data, treemap_figure
#     ^
# SyntaxError: 'return' outside function

# %%
freq_list_top
# Out:
# [0.08552631578947369,
#  0.08552631578947369,
#  0.08552631578947369,
#  0.08552631578947369,
#  0.09868421052631579,
#  0.09868421052631579,
#  0.09868421052631579,
#  0.09868421052631579,
#  0.10526315789473684,
#  0.1118421052631579,
#  0.1118421052631579,
#  0.14473684210526316,
#  0.14473684210526316,
#  0.1513157894736842,
#  0.16447368421052633,
#  0.16447368421052633,
#  0.17763157894736842,
#  0.20394736842105263,
#  0.23684210526315788,
#  0.23684210526315788,
#  0.2565789473684211,
#  0.2631578947368421,
#  0.5723684210526315,
#  0.756578947368421,
#  1.0]

# %%
word_list_top
# Out:
# ['sit',
#  's',
#  'made',
#  'idea',
#  'didn t',
#  'great',
#  'money',
#  'one',
#  'return',
#  'hang',
#  'around',
#  'use',
#  'neck',
#  'will',
#  'doesn t',
#  'small',
#  'base',
#  'hook',
#  'work',
#  'product',
#  't fit',
#  'fit around',
#  'fit',
#  'sink',
#  'faucet']

# %%
db = pd.read_csv('aws_reviews_sample.csv')

# %%
db[db['asin'] == 'x'].review.empty
# Out:
# True

# %%
print(l)
# Out:
# I have a newer style faucet in my house and the neck of this item did not even fit around the base of the faucet. I tried keeping it hooked around the water conditioner base but it would not hold. The neck of the item is very flimsy. The sponges that come with these I did not use at all as they are inferior to the ones I purchase at the dollar store.
#
# Watch the girth of your faucet! Mine faucet is wide, the hook couldn’t fit around it. I had to return it.
#
# My faucet is a large spout with built in pullout sprayer. The base is too big. Am finding other ways to use these.
#
# They should state that it only fits very narrow faucets.
#
# The product idea is genius, but our faucet is larger in diameter than the product allows so it isn't a good fit in our sink.
#
# Missing a strainer. Bag looks like it has been reused.
#
# Not made for a gooseneck faucet or one that is wide at the bottom
#
# The curve handle did not fit my faucet. I had to strap it with a tie
#
# I ordered these for myself and two daughters. They don’t fit any of our faucets. They will only work for a very slim faucet base.
#
# Did not hang like pictured.  Wouldn't fit around my faucet.
#
# Does not fit the faucet
#
# The neck handle does not fit around all kitchen sink faucets bummer
#
# I like the idea of this product but it doesn’t fit on my kitchen sink faucet.
#
# Sadly the curve is too small for today's sinks and faucets.  I'm still trying to give them away.  I should have known by looking at them so since it was my fault I am not returning them.
#
# Our faucet is too large for the hook to fit
#
# Good concept, would work if it fit on the sink although it did not. It’s only fitting for very specific sink style. Also, kind of bigger than expected.
#
# Doesn't properly fit my sink, too short from hook to strainer. I will use it, but ha e to do so differently
#
# They do not fit around any of the faucets in my house.
#
# This product did not work.  The hook to attach around your faucet is too short.  And to return it costs more than the original purchase.  DON'T waste your money on this product!!
#
# If you have a new faucet it doesn't fit around the bottom.
#
# This would be great if you have an older style faucet with a skinny base but will not fit most faucet styles of today!
#
# Do not buy. I’ve tried in a few different sinks and it does not work, does not fit. Just hangs all lopsided. Waste of money.
#
# Hook is smaller than in looks, doesn't fit around our faucet. It works but we have to hang it off the soap dispenser instead
#
# I didn't even consider that this might not fit on my sink... But it doesn't. That makes it pretty worthless to me.Even if it did fit around the faucet, it didn't have enough clearance to sit in the sink.Maybe this made for bathroom sinks?
#
# Great idea; however, it doesn’t fit any of my sinks. The curved neck that goes around the faucet is too small and it is not long enough to sit properly.  I have a Koehler in the kitchen and a generic in the laundry room.  Wish it would be redesigned as it would be handy when cleaning vegetables.
#
# One of the baskets was damaged. We kept them anyway. I like the job that it does and how it fits on the sink. I have an under mount sink so it’s hooks on my soap dispenser. I just wish it was better quality plastic. I don’t think it will last long. Maybe that’s why you get a multi pack.
#
# I was so excited for this and was disappointed to see that it only works on the newer, tall, kitchen faucets.  I have an older model and it will not fit!  I’ll keep it until I get a different faucet!
#
# Love the cuteness, design, and function, but not so universal. Doesn’t fit on our rental house sink, nor the house we just bought, and gave two away and didn’t fit in there sinks. Still using as strainer.
#
# Doesn’t really fit my sink or my mom’s properly.  But it’s ok.  Just wish the neck was longer so it worked better.
#
# Product is a great idea, but isn’t one size fits all.  I have a moen faucet and the base is too large for the hook. Other than that great product.
#
# I like the idea of this, but would be great if they would make the "head" adjustable.It doesn't fit on my faucet...
#
# Unfortunately,  this won't hang on my sink as the photos show.  I can balance it on the space between the double sink, but it falls off as soon as it's bumped.
#
# It states it will work for all sinks but does not.  I bought the set of 4 to give to family members and they all have under mounted sinks. Returning today.  But otherwise a great product and concept
#
# The size of the faucet that can be used with this product should have been indicated in the description: it can’t be used with faucets with a larger circumference. Also, the larger holes are too large to catch smaller particles.
#
# Can't use it on my sink and I waited too long to return.  Added to my Goodwill box.
#
# It's state it should or do fix most sinks. Does not fit at all.
#
# The top part that goes around the faucet area needs to be adjustable in some way for the money that you pay I'm not able to us  at all
#
# Doesn't fit around the base of my faucet. So it sits in my sink which creates clutter. It probably fit a standard fixture
#
# Did not fit our basic sink.
#
# Both my sinks it is not long enough hook to sit down in sink. But I do like having it to strain food! Just wish it was longer to sit down in the sink.
#
# The idea is awesome but it dose t fit my sink.
#
# It doesn’t fit all faucets
#
# This is a cute idea but doesn’t seem to work on any of the faucets in my home or my sisters. It is not big enough to wrap around the base of any of our faucets. The colors are also not very desirable in my opinion. Cute idea but hard pass
#
# Really bummed… says fits all faucets. Not true. It doesn’t fit to my faucet.
#
# Didn’t fit my faucet
#
# The item looked like it would fit any faucet, not so.  Since there is no mention of what type faucets it would fit I took a chance. The neck on the corner is much small than it looks.
#
# Love the idea but it didn’t fit my sink.
#
# Doesn't fit our sink. So kind of a bummer.
#
# Will not fit on my sink.  Unusable.  One star because site insisted I give a star rating. I would have submitted with zero  if possible.
#
# This is my fault, I didn't realize it was used.  Both are broken/cracked.  Not asking for a return or refund, but warning BEWARE of used-good condition.
#
# The “neck” is too short.  Tried in two different sinks and it it does not fit in either one.  Don’t waste your money or your time.  It’s going to the recycle bin or the thrift store.
#
# It does not fit my standard kitchen sink. The hook is too short and small.
#
# Did not fit my sink. Would be a cool product if it was indeed a universal fit as advertised. Going to return
#
# Not useful
#
# If you have any new style faucets, do not buy.  The area to fit around the stem of your faucet is geared for old fashioned small faucet bases.  Since this is solid plastic, there are no adjustments to be made.
#
# Product looked great but doesn’t fit any of my facets! Not useful to me at all!
#
# Does not fit my sink faucet at home or in the camper!
#
# No return apparently. Can’t use it
#
# Does not fit on my faucet!  The ad makes it look SO easy to just pop it on!
#
# Wouldn't fit my kitchen sink
#
# The hook part is too narrow.
#
# I received the item but I tried to hang it on the kitchen sink faucet and the item is too small so I cannot hang it pretty disappointed :(
#
# Waste of money
#
# lame, not worth the moneyholes are too bigneck doesn't fit on my faucet
#
# Both pieces were damaged.  One had been gouged by something and the other piece is cracked.  The neck curve does not fit my faucet/ sink. Disappointed.  Expected better.
#
# Hook did not fit my faucett
#
# It did not fit around my faucet as stated.
#
# Didn't fit around my kitchen sink
#
# I couldn’t use it because the hook was too small and didn’t fit my facet. Total waste of money because I missed the return window.
#
# broken on arrival, didn't fit sinks in my home, nor in the home of three others
#
# Gross, cheap product that does not fit modern spigots
#
# Product is supposed to fit all faucets, and it doesn't.  I just purcahsed and had to return because it was not compatible with my faucet
#
# This didn't fit around my kitchen faucet, so I thought about giving it to a friend or family member, but it didn't fit on any of those I tried.
#
# Hook was not large enough to go around faucet!
# nan
# It does not fit all sinks and faucets.
#
# They would be a great product but they do not work on any sink I own the offset is not large enough
#
# The newer faucets are way too big at the base for the drain to hang on.
#
# Doesn't fit any si k. Waste of money
#
# Unable to use with a sink unless the base is round and a certain size.  Doesn't set like it shows on pictures.  Be advised.
#
# Received my strainers and attempted to put one on my kitchen faucet but the hook was too small to wrap around the faucet base.  So in order to use it as intended, I will have to cut the gooseneck in order for it to fit around the base of the faucet or just sit it in the sink like every other strainer that I have.
#
# This is a great product but didn’t fit my faucet so I can’t use as designed. I can still us it but it has to sit down in the sink.
#
# Doesn’t fit around my faucet. I have a normal sink, nothing to big or fancy and this doesn’t fit.
#
# The video I saw made this look like it would fit most universal sinks but guess what.... they don't.  It doesn't fit around the pipe of the spout nor will it stay put to use it appropriately.  Great idea in theory but needs work.  I could probably just lay it in the bottom of the sink but that isn't why I wanted this, so I'm returning the 4 pack or selling them at a garage sale.
#
# I only need two, so I just threw the other two away, but I expected the plastic to be sturdier. I do not recommend these based on the poor quality. The design is great though, so if they used higher quality plastic that would be better.
#
# I was excited to get these -- they looked like they would work. However, after using them, I have found that my faucet is too wide. It works okay, but not the best.
#
# I purchased these because I thought I could use them, however the faucet at my sink is in a location that I cannot use it.I will check with my kids and grandkids to see if they work for them, if not I will have to return them.
#
# Take a good look at your faucet before purchasing. They won’t work on mine. I’m prob going to go buy a suction hook to put near the sink on the counter. Hopefully that will work.
#
# We have a standard size faucet at the kitchen sink. However, the hook on this strainer doesn’t fit around it like it shows in the ad. Disappointing.
#
# I really like this product. The only thing that I don't like is that the curved hook is way to large . It falls off the standard size kitchen  sink faucet . It doesn't curve around enough . I think it is made for the new model faucets that are thicker at the bottom . It is not made with any suction so it's constantly falling off but it does its job
#
# Don’t fit on my faucet very well. Won’t do what designed for or what I wanted ONE for. Why they only come in multiple packages is beyond me.
#
# Too ugly for sink. The concept was good but the product is useless
#
# I have an over size faucet and the neck is too small to hang in corner of sink.
#
# It didn't fit my faucet. Make sure you check the size
#
# Small attatchment hook. Be sure to measure your faucet!
#
# Great idea, ordered 4pack, arrived today and does not fit around base of my Kitchen  faucet,ugh
#
# Didn’t fit my fsucet
#
# Great idea but unfortunately this didn’t fit around my faucet. Nowhere to hang it off of. Works fine sitting in sink but defeats the purpose.  Disappointed it says fits all.
#
# This product doesn’t fit all sinks
#
# Not big enough for the faucet
#
# Deceiving pictures doesn’t show it on a real sink faucet! Too big and not long enough. Very disappointed ☹️
#
# Easy to clean and sturdy. Suction does not spply
#
# these "swan" baskets do not fit my faucet. I returned them and they WILL NOT REFUND MY MONEY. They gave me a dredit with their company. I am a premiun account holder. They said to keep the product instead of returning, what a gimmick!
#
# As described in the product information - that the product fits all faucets - NOT true!!  The product did not fit around my faucet base - totally disappointed but will keep since I had decided to purchase for some family/friends too - hoping the product will fit around their faucet bases???  Was totally looking forward to this product doing exactly what the definition said because it would have been a most useful product since often cooking requires this (potentially) convenient drainage.  Oh, well, things are not always what they appear and or say!
#
# They do not fit on my kitchen faucet. Nor do they fit on the faucets of the people I shared them with
#
# it did not reach around the base of my faucet  But as a strainer it works great
#
# They are well made. But they did not fit around the base of my kitchen faucet.
#
# Doesn’t fit all sinks
#
# I thought these would have bendable heads to conform to different sinks. They are hard plastic and would fit few sinks. Had to return. P
#
# It was too small to hang on my faucet. It popped up in the air and wouldn't sit flatUseless.
#
# I tried it on 2 different sinks. Does not work as pictured. Sink base too wide.
#
# They did not fit my faucets.
#
# I love the idea, bit it does not fit around my sink faucet.  I sit it in the sink, but it is basically useless.
#
# The neck on this item is not long enough to fit most sinks.  Poor product, not flexible enough, plastic too hard
#
# Didn’t fit my kitchen faucet so had to return! Soooo disappointed
#
# Neck too small to fit around average sink faucet
#
# Did not fit around faucet and did not strain well.
#
# Disliked that it didn’t fit faucet, broken, and defective
#
# These do not fit the corner of my sink nor around the facet. Sadly, I missed the rerun window. I love the idea though. I wish the neck was a little more flexible to go around my facet’s base.
#
# Returned.  They didn't fit my sink hardware.
#
# I tried the swan on three different kitchen sinks and it didn’t fit any of them.
#
# I love the idea but… it doesn’t stay in place for me at all and the 4 pack I have no use for even two…
#
# sent back  does not fit and not as pictured....all hooks in same direction not two left and two facing right
#
# Will not fit on a large base faucet
#
# Doesn't wrap around kitchen faucet.
#
# Does not fit all faucets…….
#
# I THOUGHT I WOULD LIKE THIS PRODUCT BUT IT WILL NOT FIT MY SINK!!! SO AS IT TURNES OUT I HAVE NO USE FOR THEM...
#
# Does not fit on any sink I have tried it on
#
# Doesn't fit wider faucets
#
# They fit no sink. The curves to go around the faucet all went same direction this fit no sink. Very disappointed
#
# The neck is not long enough to attach to my faucet and hang over the sink.  Sending it back. One does not fit all.
#
# Did not work for my faucet setup. Looks great in the advertising video but not practical for all sink types.
#
# It does the job though it doesn't line up with the faucet to hang right. It does sit in the corner but if too much weight gets in it, it will tip and spill. A little disappointed that it didn't sit right with my sink.
#
# This product does not work for all sink types. It’s a great concept and would be perfect for the right kind of sink. I sadly didn’t have a sink it would work with.
#
# I purchased two pack of this item to divide between myself and my daughter-in-law’s. These do not fit in my sink. They also did not fit in one of my daughter-in-law’s sink. I haven’t given the other girls them yet but I’m guessing they won’t work in theirs either. Safe your money.
#
# Does what I need but doesn’t work for my sink so I had to modify.
#
# This didn’t fix around the faucet like it says it will!
#
# very cheaply made and was cracked when i received it.  Did not fit around my faucet either.
#
# Did not fit my sink and I have returned them
#
# These work great if you have a standard sink/faucet
#
# Cool concept but needs work. It didn’t fit my sink the way I thought it would.Be aware: you need a very specific size and type of sink and faucet for it to work. It’s really not very universal. It’s small, and not a great value for the price in my opinion. This would be a cool item if it was a better design.
#
# Cheaply made
#
# Doesn't fit around the Moen faucet.
#
# as above does not fit my kitchen facet,  they did return my money
#
# The product was as it was described but it doesn't fit thick faucets. If you have a kitchen faucet that has a pull out sprayer, this product will not fit.
#
# Doesn’t fit sink nozzle
#
# This does not fit my faucet. Not even close.  A total waste of my money.  I believe it was shipped from overseas, so it is next to impossible to return and get a refund.  Looks like it will be donated to a thrift store.
#
# It was simply a piece of garbage - would not fit either my sink or most sinks I know of. The little hook would fit around only the oldest faucets. And it comes from an address of Joe Doe in Delaware - web page based in China. I checked BBB - seeing the Joe Doe in the return address raised red flags in my mind. Amazon did refund my money right away.
#
# When I saw these I knew I wanted them, so I ordered. It took a while to get them. When they did arrive, of course, I tried them on my kitchen sink right away. Whomp, whomp ... a good idea, but doesn't fit all faucets. I don't even know how to suggest what faucet it would work on. It didn't fit in the corner of my sink, it was more on top
#
# The basket itself is pretty sturdy, but the neck that is supposed to hang on your faucet is really flimsy and can't handle much weight at all.
#
# They do not fit on typical single faucets. The hook part is not nearly big enough to fit around the faucet to hang over the sink. The neck is not long enough either even if the hook would accommodate the faucet. These looked useful but sadly are not.
#
# Doesn't fit universally. Wish the hook was made for a range of a few sizes bigger/wider. The hook is too shallow. Wish they came up with an adjustable type hook or closure. I have to manually set up down on my sink and it gets buried under dishes easily, making it inaccessible when I need it most. It won't even stay put on the corner lip of the sink.
#
# Does not fit around all faucets
#
# Too awkward. I purchased thinking it would stop the food going into sink strainer.  Food went right though holes in product defeating the reason I purchased it.  Products was a lot larger than I expected.
#
# Very well made it just doesn’t fit on my faucet which makes it useless to me. Nice product I just wish it fit all faucets
#
# Doesn't fit around faucet, very disappointed. I tossed it
#
# Darn what a good idea, but the swan neck was too small to fit around our faucet base. I still use it in the sink, but do measure if you want to hang this as shown.
#
# Did not fit my kitchen faucet too small returning.
#
# Can't use. It doesn't fit my sink facet at all. Sorry!!!!
#
# It was constructed well, small inside basket the perimeter was too thickly made although it was sturdy.
#
# Have a basic sink, common faucet size, but wouldn't fit around it. Pretty disappointing...
#
# Wouldn't work for my sink Sent back
#
# Awesome concept but it didn't fit my sink/faucet.
#
# Super versatile for straining leftovers off dishes or rinsing out sink drains but the neck needs to be a bit longer and wider.
#
# Doesn’t fit many sink faucets.
#
# I wish the hook was a little bigger.  It didn't fit around the base of my faucet.
#
# Nice idea but my faucet has a wide base and the handle on the product does not fit.
#
# The fit was not as good as I thought it would be don't waste your money
#
# Didn’t fit around my standard faucet.
#
# I returned these because they didn’t fit well and  too small to hold very much in them.
#
# I am keeping them because I can find a way to make them work. Maybe. But while they fit around the neck of my faucet they do not sit on the corner of the sink as shown in the description. I have two standard size sinks and it doesn’t fit either one.
#
# After watching the videos I decided that I needed these Swan Sink Drainers. Someone had a great idea but it's just too bad that they didn't fit my sink or any of my friends sinks that I tried to give them too. They appear to be made for a very small sink. I donated them to a thrift store.
#
# Read the description carefully.  (I didn't and could not use it because the diameter was too small for our faucet.  It would be great if it fit.
#
# I guess it is very useful if it fit my faucet, but it does not at all.  Still usable though
#
# Dislike how large this is
#
# Very difficult to put around faucet. Hard to remove without fear of breaking
#
# Would love to use but too short for my faucet.
#
# Its a great idea but doesnt fit on my sink. Might want to add in what sinks it does fit on.
#
# Neck too small for our faucet. But it works , and I like it.
#
# They don't fit my sink. Can't use
#
# I was excited to get these after seeing how they work.  But the way my faucet is put on and the space between the 2 sinks.  It won't hook on and sit flat.
#
# the basket is a great idea, but it can only fit around smaller faucets... way too small for the body of my regular sized faucet
#
# The yellow one was fine. The blue one was so dirty I threw it away.
#
# I have a standard size sink and this is just too big. The holder doesn’t fit around my faucet and the basket takes up too much room. It is a great tool though and super easy to clean.
#
# My facet has the two spigots on each side and blocked the neck of the strainer from hanging on the spigot.
#
# Looks like it would be awesome, but doesn't fit my style kitchen sink.  Grateful for easy return.
#
# Does not fit my faucet. you need to give the measurements and state so.
#
# It doesn’t fit a square faucet base. It never occurred to me to check if it would work on a square faucet base. it sadly does not.
#
# Won’t fit around faucet base probably won’t fit most new faucets
#
# Didn't fit my sink faucet
#
# I was pumped to get these but slightly disappointed when I did. I have the most common & average sink/faucet set up & these do not hook around the faucet as advertised. I placed one in the outer corner & set a heavy soap pump on it & it stays put while holding multiple different brushes/scrubbies so it worked out ok. Just not as intended.
#
# The blue is not a turquoise it's a baby blue. They're not really very sturdy, seem very flimsy
#
# Hangs loosely and food drops out of it.
#
# Product did not work as described.
#
# It's a great idea. But n ck is to small for most faucets.I'm sad.I really wanted to use it.
#
# The swan neck too small & the basket so big that it would not fit down in my sink.  I returned them.
#
# The loops are too stiff and did not fit around my faucet.  Waste of money and time.  Returned.
#
# It does not fit all sinks or faucets neck, it’s useless but couldn’t not return it back
#
# Holes aren’t punched all the way thru. Doesn’t work the best with sinks with space between the faucet and the sink.
#
# Don't count on this fitting your faucet! Handle is short...won't fit my sink .
#
# Little hook is too short and narrow to fit standard American sinks. Took forever to get.
#
# not long enough to work in sink
#
# Will not hook around any faucet in my house. Way to small. I will still use, just wish it would work as stated.
#
# Product make was sturdy and good, but the hook won’t fit a lot of modern sinks
#
# I can't even use them they came smashed together you can't get them apart
#
# Does not fit at all. Don’t waste your money
#
# These do not fit my faucet.
#
# The handle is to small it doesn't fit the faucet I had to hang in on the soap dispenser.
#
# It doesn’t fit on sink at all
#
# It doesn’t fit on my faucet

# %%
l = ''
[i for i in df[df['asin'] == 'B09S6FWS7W'].review]
    l = l+str(i)
l
# Out:
# ['\nI have a newer style faucet in my house and the neck of this item did not even fit around the base of the faucet. I tried keeping it hooked around the water conditioner base but it would not hold. The neck of the item is very flimsy. The sponges that come with these I did not use at all as they are inferior to the ones I purchase at the dollar store.\n',
#  '\nWatch the girth of your faucet! Mine faucet is wide, the hook couldn’t fit around it. I had to return it.\n',
#  '\nMy faucet is a large spout with built in pullout sprayer. The base is too big. Am finding other ways to use these.\n',
#  '\nThey should state that it only fits very narrow faucets.\n',
#  "\nThe product idea is genius, but our faucet is larger in diameter than the product allows so it isn't a good fit in our sink.\n",
#  '\nMissing a strainer. Bag looks like it has been reused.\n',
#  '\nNot made for a gooseneck faucet or one that is wide at the bottom\n',
#  '\nThe curve handle did not fit my faucet. I had to strap it with a tie\n',
#  '\nI ordered these for myself and two daughters. They don’t fit any of our faucets. They will only work for a very slim faucet base.\n',
#  "\nDid not hang like pictured.  Wouldn't fit around my faucet.\n",
#  '\nDoes not fit the faucet\n',
#  '\nThe neck handle does not fit around all kitchen sink faucets bummer\n',
#  '\nI like the idea of this product but it doesn’t fit on my kitchen sink faucet.\n',
#  "\nSadly the curve is too small for today's sinks and faucets.  I'm still trying to give them away.  I should have known by looking at them so since it was my fault I am not returning them.\n",
#  '\nOur faucet is too large for the hook to fit\n',
#  '\nGood concept, would work if it fit on the sink although it did not. It’s only fitting for very specific sink style. Also, kind of bigger than expected.\n',
#  "\nDoesn't properly fit my sink, too short from hook to strainer. I will use it, but ha e to do so differently\n",
#  '\nThey do not fit around any of the faucets in my house.\n',
#  "\nThis product did not work.  The hook to attach around your faucet is too short.  And to return it costs more than the original purchase.  DON'T waste your money on this product!!\n",
#  "\nIf you have a new faucet it doesn't fit around the bottom.\n",
#  '\nThis would be great if you have an older style faucet with a skinny base but will not fit most faucet styles of today!\n',
#  '\nDo not buy. I’ve tried in a few different sinks and it does not work, does not fit. Just hangs all lopsided. Waste of money.\n',
#  "\nHook is smaller than in looks, doesn't fit around our faucet. It works but we have to hang it off the soap dispenser instead\n",
#  "\nI didn't even consider that this might not fit on my sink... But it doesn't. That makes it pretty worthless to me.Even if it did fit around the faucet, it didn't have enough clearance to sit in the sink.Maybe this made for bathroom sinks?\n",
#  '\nGreat idea; however, it doesn’t fit any of my sinks. The curved neck that goes around the faucet is too small and it is not long enough to sit properly.  I have a Koehler in the kitchen and a generic in the laundry room.  Wish it would be redesigned as it would be handy when cleaning vegetables.\n',
#  '\nOne of the baskets was damaged. We kept them anyway. I like the job that it does and how it fits on the sink. I have an under mount sink so it’s hooks on my soap dispenser. I just wish it was better quality plastic. I don’t think it will last long. Maybe that’s why you get a multi pack.\n',
#  '\nI was so excited for this and was disappointed to see that it only works on the newer, tall, kitchen faucets.  I have an older model and it will not fit!  I’ll keep it until I get a different faucet!\n',
#  '\nLove the cuteness, design, and function, but not so universal. Doesn’t fit on our rental house sink, nor the house we just bought, and gave two away and didn’t fit in there sinks. Still using as strainer.\n',
#  '\nDoesn’t really fit my sink or my mom’s properly.  But it’s ok.  Just wish the neck was longer so it worked better.\n',
#  '\nProduct is a great idea, but isn’t one size fits all.  I have a moen faucet and the base is too large for the hook. Other than that great product.\n',
#  '\nI like the idea of this, but would be great if they would make the "head" adjustable.It doesn\'t fit on my faucet...\n',
#  "\nUnfortunately,  this won't hang on my sink as the photos show.  I can balance it on the space between the double sink, but it falls off as soon as it's bumped.\n",
#  '\nIt states it will work for all sinks but does not.  I bought the set of 4 to give to family members and they all have under mounted sinks. Returning today.  But otherwise a great product and concept\n',
#  '\nThe size of the faucet that can be used with this product should have been indicated in the description: it can’t be used with faucets with a larger circumference. Also, the larger holes are too large to catch smaller particles.\n',
#  "\nCan't use it on my sink and I waited too long to return.  Added to my Goodwill box.\n",
#  "\nIt's state it should or do fix most sinks. Does not fit at all.\n",
#  "\nThe top part that goes around the faucet area needs to be adjustable in some way for the money that you pay I'm not able to us  at all\n",
#  "\nDoesn't fit around the base of my faucet. So it sits in my sink which creates clutter. It probably fit a standard fixture\n",
#  '\nDid not fit our basic sink.\n',
#  '\nBoth my sinks it is not long enough hook to sit down in sink. But I do like having it to strain food! Just wish it was longer to sit down in the sink.\n',
#  '\nThe idea is awesome but it dose t fit my sink.\n',
#  '\nIt doesn’t fit all faucets\n',
#  '\nThis is a cute idea but doesn’t seem to work on any of the faucets in my home or my sisters. It is not big enough to wrap around the base of any of our faucets. The colors are also not very desirable in my opinion. Cute idea but hard pass\n',
#  '\nReally bummed… says fits all faucets. Not true. It doesn’t fit to my faucet.\n',
#  '\nDidn’t fit my faucet\n',
#  '\nThe item looked like it would fit any faucet, not so.  Since there is no mention of what type faucets it would fit I took a chance. The neck on the corner is much small than it looks.\n',
#  '\nLove the idea but it didn’t fit my sink.\n',
#  "\nDoesn't fit our sink. So kind of a bummer.\n",
#  '\nWill not fit on my sink.  Unusable.  One star because site insisted I give a star rating. I would have submitted with zero  if possible.\n',
#  "\nThis is my fault, I didn't realize it was used.  Both are broken/cracked.  Not asking for a return or refund, but warning BEWARE of used-good condition.\n",
#  '\nThe “neck” is too short.  Tried in two different sinks and it it does not fit in either one.  Don’t waste your money or your time.  It’s going to the recycle bin or the thrift store.\n',
#  '\nIt does not fit my standard kitchen sink. The hook is too short and small.\n',
#  '\nDid not fit my sink. Would be a cool product if it was indeed a universal fit as advertised. Going to return\n',
#  '\nNot useful\n',
#  '\nIf you have any new style faucets, do not buy.  The area to fit around the stem of your faucet is geared for old fashioned small faucet bases.  Since this is solid plastic, there are no adjustments to be made.\n',
#  '\nProduct looked great but doesn’t fit any of my facets! Not useful to me at all!\n',
#  '\nDoes not fit my sink faucet at home or in the camper!\n',
#  '\nNo return apparently. Can’t use it\n',
#  '\nDoes not fit on my faucet!  The ad makes it look SO easy to just pop it on!\n',
#  "\nWouldn't fit my kitchen sink\n",
#  '\nThe hook part is too narrow.\n',
#  '\nI received the item but I tried to hang it on the kitchen sink faucet and the item is too small so I cannot hang it pretty disappointed :(\n',
#  '\nWaste of money\n',
#  "\nlame, not worth the moneyholes are too bigneck doesn't fit on my faucet\n",
#  '\nBoth pieces were damaged.  One had been gouged by something and the other piece is cracked.  The neck curve does not fit my faucet/ sink. Disappointed.  Expected better.\n',
#  '\nHook did not fit my faucett\n',
#  '\nIt did not fit around my faucet as stated.\n',
#  "\nDidn't fit around my kitchen sink\n",
#  '\nI couldn’t use it because the hook was too small and didn’t fit my facet. Total waste of money because I missed the return window.\n',
#  "\nbroken on arrival, didn't fit sinks in my home, nor in the home of three others\n",
#  '\nGross, cheap product that does not fit modern spigots\n',
#  "\nProduct is supposed to fit all faucets, and it doesn't.  I just purcahsed and had to return because it was not compatible with my faucet\n",
#  "\nThis didn't fit around my kitchen faucet, so I thought about giving it to a friend or family member, but it didn't fit on any of those I tried.\n",
#  '\nHook was not large enough to go around faucet!\n',
#  nan,
#  '\nIt does not fit all sinks and faucets.\n',
#  '\nThey would be a great product but they do not work on any sink I own the offset is not large enough\n',
#  '\nThe newer faucets are way too big at the base for the drain to hang on.\n',
#  "\nDoesn't fit any si k. Waste of money\n",
#  "\nUnable to use with a sink unless the base is round and a certain size.  Doesn't set like it shows on pictures.  Be advised.\n",
#  '\nReceived my strainers and attempted to put one on my kitchen faucet but the hook was too small to wrap around the faucet base.  So in order to use it as intended, I will have to cut the gooseneck in order for it to fit around the base of the faucet or just sit it in the sink like every other strainer that I have.\n',
#  '\nThis is a great product but didn’t fit my faucet so I can’t use as designed. I can still us it but it has to sit down in the sink.\n',
#  '\nDoesn’t fit around my faucet. I have a normal sink, nothing to big or fancy and this doesn’t fit.\n',
#  "\nThe video I saw made this look like it would fit most universal sinks but guess what.... they don't.  It doesn't fit around the pipe of the spout nor will it stay put to use it appropriately.  Great idea in theory but needs work.  I could probably just lay it in the bottom of the sink but that isn't why I wanted this, so I'm returning the 4 pack or selling them at a garage sale.\n",
#  '\nI only need two, so I just threw the other two away, but I expected the plastic to be sturdier. I do not recommend these based on the poor quality. The design is great though, so if they used higher quality plastic that would be better.\n',
#  '\nI was excited to get these -- they looked like they would work. However, after using them, I have found that my faucet is too wide. It works okay, but not the best.\n',
#  '\nI purchased these because I thought I could use them, however the faucet at my sink is in a location that I cannot use it.I will check with my kids and grandkids to see if they work for them, if not I will have to return them.\n',
#  '\nTake a good look at your faucet before purchasing. They won’t work on mine. I’m prob going to go buy a suction hook to put near the sink on the counter. Hopefully that will work.\n',
#  '\nWe have a standard size faucet at the kitchen sink. However, the hook on this strainer doesn’t fit around it like it shows in the ad. Disappointing.\n',
#  "\nI really like this product. The only thing that I don't like is that the curved hook is way to large . It falls off the standard size kitchen  sink faucet . It doesn't curve around enough . I think it is made for the new model faucets that are thicker at the bottom . It is not made with any suction so it's constantly falling off but it does its job\n",
#  '\nDon’t fit on my faucet very well. Won’t do what designed for or what I wanted ONE for. Why they only come in multiple packages is beyond me.\n',
#  '\nToo ugly for sink. The concept was good but the product is useless\n',
#  '\nI have an over size faucet and the neck is too small to hang in corner of sink.\n',
#  "\nIt didn't fit my faucet. Make sure you check the size\n",
#  '\nSmall attatchment hook. Be sure to measure your faucet!\n',
#  '\nGreat idea, ordered 4pack, arrived today and does not fit around base of my Kitchen  faucet,ugh\n',
#  '\nDidn’t fit my fsucet\n',
#  '\nGreat idea but unfortunately this didn’t fit around my faucet. Nowhere to hang it off of. Works fine sitting in sink but defeats the purpose.  Disappointed it says fits all.\n',
#  '\nThis product doesn’t fit all sinks\n',
#  '\nNot big enough for the faucet\n',
#  '\nDeceiving pictures doesn’t show it on a real sink faucet! Too big and not long enough. Very disappointed ☹️\n',
#  '\nEasy to clean and sturdy. Suction does not spply\n',
#  '\nthese "swan" baskets do not fit my faucet. I returned them and they WILL NOT REFUND MY MONEY. They gave me a dredit with their company. I am a premiun account holder. They said to keep the product instead of returning, what a gimmick!\n',
#  '\nAs described in the product information - that the product fits all faucets - NOT true!!  The product did not fit around my faucet base - totally disappointed but will keep since I had decided to purchase for some family/friends too - hoping the product will fit around their faucet bases???  Was totally looking forward to this product doing exactly what the definition said because it would have been a most useful product since often cooking requires this (potentially) convenient drainage.  Oh, well, things are not always what they appear and or say!\n',
#  '\nThey do not fit on my kitchen faucet. Nor do they fit on the faucets of the people I shared them with\n',
#  '\nit did not reach around the base of my faucet  But as a strainer it works great\n',
#  '\nThey are well made. But they did not fit around the base of my kitchen faucet.\n',
#  '\nDoesn’t fit all sinks\n',
#  '\nI thought these would have bendable heads to conform to different sinks. They are hard plastic and would fit few sinks. Had to return. P\n',
#  "\nIt was too small to hang on my faucet. It popped up in the air and wouldn't sit flatUseless.\n",
#  '\nI tried it on 2 different sinks. Does not work as pictured. Sink base too wide.\n',
#  '\nThey did not fit my faucets.\n',
#  '\nI love the idea, bit it does not fit around my sink faucet.  I sit it in the sink, but it is basically useless.\n',
#  '\nThe neck on this item is not long enough to fit most sinks.  Poor product, not flexible enough, plastic too hard\n',
#  '\nDidn’t fit my kitchen faucet so had to return! Soooo disappointed\n',
#  '\nNeck too small to fit around average sink faucet\n',
#  '\nDid not fit around faucet and did not strain well.\n',
#  '\nDisliked that it didn’t fit faucet, broken, and defective\n',
#  '\nThese do not fit the corner of my sink nor around the facet. Sadly, I missed the rerun window. I love the idea though. I wish the neck was a little more flexible to go around my facet’s base.\n',
#  "\nReturned.  They didn't fit my sink hardware.\n",
#  '\nI tried the swan on three different kitchen sinks and it didn’t fit any of them.\n',
#  '\nI love the idea but… it doesn’t stay in place for me at all and the 4 pack I have no use for even two…\n',
#  '\nsent back  does not fit and not as pictured....all hooks in same direction not two left and two facing right\n',
#  '\nWill not fit on a large base faucet\n',
#  "\nDoesn't wrap around kitchen faucet.\n",
#  '\nDoes not fit all faucets…….\n',
#  '\nI THOUGHT I WOULD LIKE THIS PRODUCT BUT IT WILL NOT FIT MY SINK!!! SO AS IT TURNES OUT I HAVE NO USE FOR THEM...\n',
#  '\nDoes not fit on any sink I have tried it on\n',
#  "\nDoesn't fit wider faucets\n",
#  '\nThey fit no sink. The curves to go around the faucet all went same direction this fit no sink. Very disappointed\n',
#  '\nThe neck is not long enough to attach to my faucet and hang over the sink.  Sending it back. One does not fit all.\n',
#  '\nDid not work for my faucet setup. Looks great in the advertising video but not practical for all sink types.\n',
#  "\nIt does the job though it doesn't line up with the faucet to hang right. It does sit in the corner but if too much weight gets in it, it will tip and spill. A little disappointed that it didn't sit right with my sink.\n",
#  '\nThis product does not work for all sink types. It’s a great concept and would be perfect for the right kind of sink. I sadly didn’t have a sink it would work with.\n',
#  '\nI purchased two pack of this item to divide between myself and my daughter-in-law’s. These do not fit in my sink. They also did not fit in one of my daughter-in-law’s sink. I haven’t given the other girls them yet but I’m guessing they won’t work in theirs either. Safe your money.\n',
#  '\nDoes what I need but doesn’t work for my sink so I had to modify.\n',
#  '\nThis didn’t fix around the faucet like it says it will!\n',
#  '\nvery cheaply made and was cracked when i received it.  Did not fit around my faucet either.\n',
#  '\nDid not fit my sink and I have returned them\n',
#  '\nThese work great if you have a standard sink/faucet\n',
#  '\nCool concept but needs work. It didn’t fit my sink the way I thought it would.Be aware: you need a very specific size and type of sink and faucet for it to work. It’s really not very universal. It’s small, and not a great value for the price in my opinion. This would be a cool item if it was a better design.\n',
#  '\nCheaply made\n',
#  "\nDoesn't fit around the Moen faucet.\n",
#  '\nas above does not fit my kitchen facet,  they did return my money\n',
#  "\nThe product was as it was described but it doesn't fit thick faucets. If you have a kitchen faucet that has a pull out sprayer, this product will not fit.\n",
#  '\nDoesn’t fit sink nozzle\n',
#  '\nThis does not fit my faucet. Not even close.  A total waste of my money.  I believe it was shipped from overseas, so it is next to impossible to return and get a refund.  Looks like it will be donated to a thrift store.\n',
#  '\nIt was simply a piece of garbage - would not fit either my sink or most sinks I know of. The little hook would fit around only the oldest faucets. And it comes from an address of Joe Doe in Delaware - web page based in China. I checked BBB - seeing the Joe Doe in the return address raised red flags in my mind. Amazon did refund my money right away.\n',
#  "\nWhen I saw these I knew I wanted them, so I ordered. It took a while to get them. When they did arrive, of course, I tried them on my kitchen sink right away. Whomp, whomp ... a good idea, but doesn't fit all faucets. I don't even know how to suggest what faucet it would work on. It didn't fit in the corner of my sink, it was more on top\n",
#  "\nThe basket itself is pretty sturdy, but the neck that is supposed to hang on your faucet is really flimsy and can't handle much weight at all.\n",
#  '\nThey do not fit on typical single faucets. The hook part is not nearly big enough to fit around the faucet to hang over the sink. The neck is not long enough either even if the hook would accommodate the faucet. These looked useful but sadly are not.\n',
#  "\nDoesn't fit universally. Wish the hook was made for a range of a few sizes bigger/wider. The hook is too shallow. Wish they came up with an adjustable type hook or closure. I have to manually set up down on my sink and it gets buried under dishes easily, making it inaccessible when I need it most. It won't even stay put on the corner lip of the sink.\n",
#  '\nDoes not fit around all faucets\n',
#  '\nToo awkward. I purchased thinking it would stop the food going into sink strainer.  Food went right though holes in product defeating the reason I purchased it.  Products was a lot larger than I expected.\n',
#  '\nVery well made it just doesn’t fit on my faucet which makes it useless to me. Nice product I just wish it fit all faucets\n',
#  "\nDoesn't fit around faucet, very disappointed. I tossed it\n",
#  '\nDarn what a good idea, but the swan neck was too small to fit around our faucet base. I still use it in the sink, but do measure if you want to hang this as shown.\n',
#  '\nDid not fit my kitchen faucet too small returning.\n',
#  "\nCan't use. It doesn't fit my sink facet at all. Sorry!!!!\n",
#  '\nIt was constructed well, small inside basket the perimeter was too thickly made although it was sturdy.\n',
#  "\nHave a basic sink, common faucet size, but wouldn't fit around it. Pretty disappointing...\n",
#  "\nWouldn't work for my sink Sent back\n",
#  "\nAwesome concept but it didn't fit my sink/faucet.\n",
#  '\nSuper versatile for straining leftovers off dishes or rinsing out sink drains but the neck needs to be a bit longer and wider.\n',
#  '\nDoesn’t fit many sink faucets.\n',
#  "\nI wish the hook was a little bigger.  It didn't fit around the base of my faucet.\n",
#  '\nNice idea but my faucet has a wide base and the handle on the product does not fit.\n',
#  "\nThe fit was not as good as I thought it would be don't waste your money\n",
#  '\nDidn’t fit around my standard faucet.\n',
#  '\nI returned these because they didn’t fit well and  too small to hold very much in them.\n',
#  '\nI am keeping them because I can find a way to make them work. Maybe. But while they fit around the neck of my faucet they do not sit on the corner of the sink as shown in the description. I have two standard size sinks and it doesn’t fit either one.\n',
#  "\nAfter watching the videos I decided that I needed these Swan Sink Drainers. Someone had a great idea but it's just too bad that they didn't fit my sink or any of my friends sinks that I tried to give them too. They appear to be made for a very small sink. I donated them to a thrift store.\n",
#  "\nRead the description carefully.  (I didn't and could not use it because the diameter was too small for our faucet.  It would be great if it fit.\n",
#  '\nI guess it is very useful if it fit my faucet, but it does not at all.  Still usable though\n',
#  '\nDislike how large this is\n',
#  '\nVery difficult to put around faucet. Hard to remove without fear of breaking\n',
#  '\nWould love to use but too short for my faucet.\n',
#  '\nIts a great idea but doesnt fit on my sink. Might want to add in what sinks it does fit on.\n',
#  '\nNeck too small for our faucet. But it works , and I like it.\n',
#  "\nThey don't fit my sink. Can't use\n",
#  "\nI was excited to get these after seeing how they work.  But the way my faucet is put on and the space between the 2 sinks.  It won't hook on and sit flat.\n",
#  '\nthe basket is a great idea, but it can only fit around smaller faucets... way too small for the body of my regular sized faucet\n',
#  '\nThe yellow one was fine. The blue one was so dirty I threw it away.\n',
#  '\nI have a standard size sink and this is just too big. The holder doesn’t fit around my faucet and the basket takes up too much room. It is a great tool though and super easy to clean.\n',
#  '\nMy facet has the two spigots on each side and blocked the neck of the strainer from hanging on the spigot.\n',
#  "\nLooks like it would be awesome, but doesn't fit my style kitchen sink.  Grateful for easy return.\n",
#  '\nDoes not fit my faucet. you need to give the measurements and state so.\n',
#  '\nIt doesn’t fit a square faucet base. It never occurred to me to check if it would work on a square faucet base. it sadly does not.\n',
#  '\nWon’t fit around faucet base probably won’t fit most new faucets\n',
#  "\nDidn't fit my sink faucet\n",
#  '\nI was pumped to get these but slightly disappointed when I did. I have the most common & average sink/faucet set up & these do not hook around the faucet as advertised. I placed one in the outer corner & set a heavy soap pump on it & it stays put while holding multiple different brushes/scrubbies so it worked out ok. Just not as intended.\n',
#  "\nThe blue is not a turquoise it's a baby blue. They're not really very sturdy, seem very flimsy\n",
#  '\nHangs loosely and food drops out of it.\n',
#  '\nProduct did not work as described.\n',
#  "\nIt's a great idea. But n ck is to small for most faucets.I'm sad.I really wanted to use it.\n",
#  '\nThe swan neck too small & the basket so big that it would not fit down in my sink.  I returned them.\n',
#  '\nThe loops are too stiff and did not fit around my faucet.  Waste of money and time.  Returned.\n',
#  '\nIt does not fit all sinks or faucets neck, it’s useless but couldn’t not return it back\n',
#  '\nHoles aren’t punched all the way thru. Doesn’t work the best with sinks with space between the faucet and the sink.\n',
#  "\nDon't count on this fitting your faucet! Handle is short...won't fit my sink .\n",
#  '\nLittle hook is too short and narrow to fit standard American sinks. Took forever to get.\n',
#  '\nnot long enough to work in sink\n',
#  '\nWill not hook around any faucet in my house. Way to small. I will still use, just wish it would work as stated.\n',
#  '\nProduct make was sturdy and good, but the hook won’t fit a lot of modern sinks\n',
#  "\nI can't even use them they came smashed together you can't get them apart\n",
#  '\nDoes not fit at all. Don’t waste your money\n',
#  '\nThese do not fit my faucet.\n',
#  "\nThe handle is to small it doesn't fit the faucet I had to hang in on the soap dispenser.\n",
#  '\nIt doesn’t fit on sink at all\n',
#  '\nIt doesn’t fit on my faucet\n']
